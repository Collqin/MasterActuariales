# %% [markdown]
# <a href="https://colab.research.google.com/github/Collqin/MasterActuariales/blob/main/Pr%C3%A1ctica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Práctica 2: Random Walk
#
# ## Renta Variable y Derivados Financieros
#
# ### Lucía Cochón López
#
# Se nos pide crear un código que nos haga un random walk en una y/o dos dimensiones.

# %%
import random
import math
import matplotlib.pyplot as plt
random.seed()
n=100 #número de pasos
r=1 #longitud del paso

# %% [markdown]
# Paseo unidimensional:

# %%
x = 0
listax = [x]

for i in range (n):
  if random.random() < 0.5:
    r=-1*r
  x += r
  listax.append(x)

plt.plot(listax)
print("Paseo aleatorio unidimensional:", listax)
plt.show()
# Out:
# Paseo aleatorio unidimensional: [0, 1, 0, 1, 0, -1, -2, -1, 0, -1, -2, -3, -2, -1, -2, -1, -2, -3, -4, -5, -6, -7, -6, -7, -6, -5, -6, -7, -6, -7, -8, -7, -8, -7, -6, -5, -6, -7, -8, -9, -10, -11, -12, -13, -12, -11, -12, -11, -10, -9, -8, -7, -8, -9, -10, -11, -10, -9, -8, -9, -8, -9, -10, -11, -10, -9, -10, -9, -10, -9, -8, -7, -6, -5, -6, -5, -4, -5, -4, -3, -2, -1, -2, -3, -2, -1, 0, 1, 0, -1, 0, -1, -2, -1, 0, -1, 0, 1, 0, 1, 2]

# %% [markdown]
# Paseo bidimensional:

# %%
n=100 #número de pasos
r=1 #longitud del paso
x=y=0 # punto de partida (x,y) = (0,0)

listax=[x]
listay=[y]

for i in range (n):
  angulo=random.random()*math.pi*2
  x+=r*math.cos(angulo)
  y+=r*math.sin(angulo)

  listax.append(x)
  listay.append(y)

plt.plot(listax,listay)
print("Random walk bidimensional", listax,listay)
plt.show()
# Out:
# Random walk bidimensional [0, -0.6760114662078849, 0.32334100615963624, -0.2838527168010847, -0.9933904656834082, -0.2022136993898106, 0.36344794909586586, 0.26983107739270207, -0.19129975731882431, 0.7484890666490627, 1.7483355881459293, 1.0416934820973234, 2.0416603608293635, 2.9261448245439174, 2.0362336876236213, 2.4005313773814176, 3.318716457462612, 2.739241298767822, 3.735219689179957, 2.816631179430974, 3.3203393550824916, 3.5570906908980704, 4.556935083593602, 4.550594227429837, 4.004567299718229, 3.0240256278310804, 3.918365404308008, 3.994197246681265, 4.874238503869164, 4.158536758914646, 5.048209308903785, 4.769589208208085, 5.767492455758706, 4.773739313814503, 5.5620938285835475, 5.71580488273107, 6.255854302144008, 5.261029685412164, 6.221869526996677, 6.311968739547617, 5.381616218167033, 5.8484972434380635, 5.604978455543035, 5.419355869334181, 4.640550501986601, 5.600316499173513, 4.6012482971978885, 5.214706997456867, 6.1851409510309425, 6.419413796888467, 6.55992
# ...
